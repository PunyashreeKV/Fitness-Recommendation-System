# %% [markdown]
# # Fitness Exercises
#
# <img src="https://www.melarossa.it/wp-content/uploads/2019/11/30-days-superhero-fitness-challenge-750x375.jpg?x75642" alt="exercise_pic">
#
# This dataset contains all the information related to fitness exercises. The exercises are split in the following categories:
#
# <ul>
#   <li>back</li>
#   <li>cardio</li>
#   <li>chest</li>
#   <li>lower arms</li>
#   <li>lower legs</li>
#   <li>neck</li>
#   <li>shoulders</li>
#   <li>upper arms</li>
#   <li>upper legs</li>
#   <li>waist</li>
# </ul>
#
# #### Author: Doğu İlmak
#
# #### Dataset: https://www.kaggle.com/datasets/edoardoba/fitness-exercises-with-animations

# %% [markdown]
# ## 1. Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### 2.1. Uploading data

# %%
df = pd.read_csv('fitness_exercises.csv')

# %%
df
# Out:
#         bodyPart    equipment                                         gifUrl  \
# 0          waist  body weight  http://d205bpvrqc9yn1.cloudfront.net/0001.gif
# 1          waist  body weight  http://d205bpvrqc9yn1.cloudfront.net/0002.gif
# 2          waist  body weight  http://d205bpvrqc9yn1.cloudfront.net/0003.gif
# 3     upper legs  body weight  http://d205bpvrqc9yn1.cloudfront.net/1512.gif
# 4          waist  body weight  http://d205bpvrqc9yn1.cloudfront.net/0006.gif
# ...          ...          ...                                            ...
# 1322       chest  body weight  http://d205bpvrqc9yn1.cloudfront.net/2363.gif
# 1323       waist  body weight  http://d205bpvrqc9yn1.cloudfront.net/0858.gif
# 1324  upper legs  body weight  http://d205bpvrqc9yn1.cloudfront.net/1604.gif
# 1325  lower arms  body weight  http://d205bpvrqc9yn1.cloudfront.net/1428.gif
# 1326  lower arms     weighted  http://d205bpvrqc9yn1.cloudfront.net/0859.gif
#
#         id                                       name      target
# 0        1                                 3/4 sit-up         abs
# 1        2                              45° side bend         abs
# 2        3                                   air bike         abs
# 3     1512                    all fours squad stretch       quads
# 4        6                    alternate heel touchers         abs
# ...    ...                                        ...         ...
# 1322  2363  wide-grip chest dip on high parallel bars   pectorals
# 1323   858                               wind sprints         abs
# 1324  1604                     world greatest stretch  hamstrings
# 1325  1428                              wrist circles    forearms
# 1326   859                             wrist rollerer    forearms
#
# [1327 rows x 6 columns]

# %% [markdown]
# ### 2.2. Looking for null numbers

# %%
df.isnull().sum()
# Out:
# bodyPart     0
# equipment    0
# gifUrl       0
# id           0
# name         0
# target       0
# dtype: int64

# %% [markdown]
# ### 2.3. Listing columns

# %%
list(df.columns)
# Out:
# ['bodyPart', 'equipment', 'gifUrl', 'id', 'name', 'target']

# %%
df.describe().T
# Out:
#      count         mean          std  min    25%    50%     75%     max
# id  1327.0  1189.528259  1006.661464  1.0  378.5  862.0  1661.5  5201.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1327 entries, 0 to 1326
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bodyPart   1327 non-null   object
#  1   equipment  1327 non-null   object
#  2   gifUrl     1327 non-null   object
#  3   id         1327 non-null   int64
#  4   name       1327 non-null   object
#  5   target     1327 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 62.3+ KB

# %% [markdown]
# ## 3. Seperate columns

# %% [markdown]
# ### 3.1 Seperate body parts

# %%
bodyPart = df['bodyPart']
bodyPart.unique()
# Out:
# array(['waist', 'upper legs', 'back', 'lower legs', 'chest', 'upper arms',
#        'cardio', 'shoulders', 'lower arms', 'neck'], dtype=object)

# %% [markdown]
# ### 3.2 Seperate target

# %%
target = df['target']
target.unique()
# Out:
# array(['abs', 'quads', 'lats', 'calves', 'pectorals', 'glutes',
#        'hamstrings', 'adductors', 'triceps', 'cardiovascular system',
#        'spine', 'upper back', 'biceps', 'delts', 'forearms', 'traps',
#        'serratus anterior', 'abductors', 'levator scapulae'], dtype=object)

# %% [markdown]
# ### 3.3 Seperate equipment

# %%
equipment = df['equipment']
equipment.unique()
# Out:
# array(['body weight', 'cable', 'leverage machine', 'assisted',
#        'medicine ball', 'stability ball', 'band', 'barbell', 'rope',
#        'dumbbell', 'ez barbell', 'sled machine', 'upper body ergometer',
#        'kettlebell', 'olympic barbell', 'weighted', 'bosu ball',
#        'resistance band', 'roller', 'skierg machine', 'hammer',
#        'smith machine', 'wheel roller', 'stationary bike', 'tire',
#        'trap bar', 'elliptical machine', 'stepmill machine'], dtype=object)

# %% [markdown]
# ### 3.4 Seperate id

# %%
exercise_id = df['id']

# %% [markdown]
# ## 4. Filtering exercises

# %%
len(df[(df.bodyPart == 'waist') & (df.target == 'abs')])
# Out:
# 170

# %%
df[(df.bodyPart == 'waist') & (df.target == 'abs')]
# Out:
#      bodyPart     equipment                                         gifUrl  \
# 0       waist   body weight  http://d205bpvrqc9yn1.cloudfront.net/0001.gif
# 1       waist   body weight  http://d205bpvrqc9yn1.cloudfront.net/0002.gif
# 2       waist   body weight  http://d205bpvrqc9yn1.cloudfront.net/0003.gif
# 4       waist   body weight  http://d205bpvrqc9yn1.cloudfront.net/0006.gif
# 9       waist   body weight  http://d205bpvrqc9yn1.cloudfront.net/2355.gif
# ...       ...           ...                                            ...
# 1303    waist      weighted  http://d205bpvrqc9yn1.cloudfront.net/2371.gif
# 1305    waist      weighted  http://d205bpvrqc9yn1.cloudfront.net/0849.gif
# 1306    waist      weighted  http://d205bpvrqc9yn1.cloudfront.net/0850.gif
# 1317    waist  wheel roller  http://d205bpvrqc9yn1.cloudfront.net/0857.gif
# 1323    waist   body weight  http://d205bpvrqc9yn1.cloudfront.net/0858.gif
#
#         id                                       name target
# 0        1                                 3/4 sit-up    abs
# 1        2                              45° side bend    abs
# 2        3                                   air bike    abs
# 4        6                    alternate heel touchers    abs
# 9     2355        arm slingers hanging bent knee legs    abs
# ...    ...                                        ...    ...
# 1303  2371                weighted russian twist v. 2    abs
# 1305   849  weighted seated twist (on stability ball)    abs
# 1306   850     weighted side bend (on stability ball)    abs
# 1317   857                            wheel rollerout    abs
# 1323   858                               wind sprints    abs
#
# [170 rows x 6 columns]

# %%
len(df[(df.bodyPart == 'upper legs') & (df.target == 'quads')])
# Out:
# 44

# %%
df[(df.bodyPart == 'upper legs') & (df.target == 'quads')]
# Out:
#         bodyPart         equipment  \
# 3     upper legs       body weight
# 24    upper legs          assisted
# 40    upper legs       body weight
# 41    upper legs       body weight
# 64    upper legs              band
# 79    upper legs              band
# 97    upper legs           barbell
# 99    upper legs           barbell
# 103   upper legs           barbell
# 154   upper legs           barbell
# 155   upper legs           barbell
# 195   upper legs           barbell
# 196   upper legs           barbell
# 198   upper legs           barbell
# 203   upper legs           barbell
# 204   upper legs           barbell
# 205   upper legs           barbell
# 232   upper legs           barbell
# 429   upper legs       body weight
# 512   upper legs          dumbbell
# 698   upper legs          dumbbell
# 728   upper legs          dumbbell
# 729   upper legs          dumbbell
# 734   upper legs          dumbbell
# 795   upper legs          dumbbell
# 802   upper legs       body weight
# 853   upper legs              rope
# 928   upper legs  leverage machine
# 955   upper legs  leverage machine
# 1007  upper legs       body weight
# 1078  upper legs       body weight
# 1080  upper legs       body weight
# 1087  upper legs   resistance band
# 1152  upper legs       body weight
# 1178  upper legs     smith machine
# 1209  upper legs     smith machine
# 1221  upper legs           barbell
# 1227  upper legs       body weight
# 1228  upper legs           barbell
# 1229  upper legs         bosu ball
# 1230  upper legs       body weight
# 1231  upper legs       body weight
# 1255  upper legs       body weight
# 1307  upper legs          weighted
#
#                                              gifUrl    id  \
# 3     http://d205bpvrqc9yn1.cloudfront.net/1512.gif  1512
# 24    http://d205bpvrqc9yn1.cloudfront.net/1713.gif  1713
# 40    http://d205bpvrqc9yn1.cloudfront.net/1473.gif  1473
# 41    http://d205bpvrqc9yn1.cloudfront.net/0020.gif    20
# 64    http://d205bpvrqc9yn1.cloudfront.net/0987.gif   987
# 79    http://d205bpvrqc9yn1.cloudfront.net/1001.gif  1001
# 97    http://d205bpvrqc9yn1.cloudfront.net/0024.gif    24
# 99    http://d205bpvrqc9yn1.cloudfront.net/0026.gif    26
# 103   http://d205bpvrqc9yn1.cloudfront.net/0028.gif    28
# 154   http://d205bpvrqc9yn1.cloudfront.net/0068.gif    68
# 155   http://d205bpvrqc9yn1.cloudfront.net/0069.gif    69
# 195   http://d205bpvrqc9yn1.cloudfront.net/0098.gif    98
# 196   http://d205bpvrqc9yn1.cloudfront.net/0097.gif    97
# 198   http://d205bpvrqc9yn1.cloudfront.net/0099.gif    99
# 203   http://d205bpvrqc9yn1.cloudfront.net/2810.gif  2810
# 204   http://d205bpvrqc9yn1.cloudfront.net/0102.gif   102
# 205   http://d205bpvrqc9yn1.cloudfront.net/2798.gif  2798
# 232   http://d205bpvrqc9yn1.cloudfront.net/0124.gif   124
# 429   http://d205bpvrqc9yn1.cloudfront.net/1548.gif  1548
# 512   http://d205bpvrqc9yn1.cloudfront.net/1760.gif  1760
# 698   http://d205bpvrqc9yn1.cloudfront.net/0410.gif   410
# 728   http://d205bpvrqc9yn1.cloudfront.net/2796.gif  2796
# 729   http://d205bpvrqc9yn1.cloudfront.net/2812.gif  2812
# 734   http://d205bpvrqc9yn1.cloudfront.net/2803.gif  2803
# 795   http://d205bpvrqc9yn1.cloudfront.net/2133.gif  2133
# 802   http://d205bpvrqc9yn1.cloudfront.net/1472.gif  1472
# 853   http://d205bpvrqc9yn1.cloudfront.net/1564.gif  1564
# 928   http://d205bpvrqc9yn1.cloudfront.net/2287.gif  2287
# 955   http://d205bpvrqc9yn1.cloudfront.net/0585.gif   585
# 1007  http://d205bpvrqc9yn1.cloudfront.net/0613.gif   613
# 1078  http://d205bpvrqc9yn1.cloudfront.net/3533.gif  3533
# 1080  http://d205bpvrqc9yn1.cloudfront.net/3552.gif  3552
# 1087  http://d205bpvrqc9yn1.cloudfront.net/3007.gif  3007
# 1152  http://d205bpvrqc9yn1.cloudfront.net/1489.gif  1489
# 1178  http://d205bpvrqc9yn1.cloudfront.net/0750.gif   750
# 1209  http://d205bpvrqc9yn1.cloudfront.net/0768.gif   768
# 1221  http://d205bpvrqc9yn1.cloudfront.net/0776.gif   776
# 1227  http://d205bpvrqc9yn1.cloudfront.net/2368.gif  2368
# 1228  http://d205bpvrqc9yn1.cloudfront.net/0786.gif   786
# 1229  http://d205bpvrqc9yn1.cloudfront.net/1705.gif  1705
# 1230  http://d205bpvrqc9yn1.cloudfront.net/1685.gif  1685
# 1231  http://d205bpvrqc9yn1.cloudfront.net/1686.gif  1686
# 1255  http://d205bpvrqc9yn1.cloudfront.net/0809.gif   809
# 1307  http://d205bpvrqc9yn1.cloudfront.net/0851.gif   851
#
#                                           name target
# 3                      all fours squad stretch  quads
# 24          assisted prone lying quads stretch  quads
# 40                               backward jump  quads
# 41                               balance board  quads
# 64         band one arm single leg split squat  quads
# 79                 band single leg split squat  quads
# 97                   barbell bench front squat  quads
# 99                         barbell bench squat  quads
# 103                    barbell clean and press  quads
# 154                      barbell one leg squat  quads
# 155                     barbell overhead squat  quads
# 195                   barbell side split squat  quads
# 196              barbell side split squat v. 2  quads
# 198             barbell single leg split squat  quads
# 203                   barbell split squat v. 2  quads
# 204                   barbell squat (on knees)  quads
# 205         barbell squat jump step rear lunge  quads
# 232                         barbell wide squat  quads
# 429                 chair leg extended stretch  quads
# 512                      dumbbell goblet squat  quads
# 698            dumbbell single leg split squat  quads
# 728                     dumbbell step-up lunge  quads
# 729               dumbbell step-up split squat  quads
# 734                   dumbbell supported squat  quads
# 795                               farmers walk  quads
# 802                               forward jump  quads
# 853   intermediate hip flexor and quad stretch  quads
# 928                 lever alternate leg press   quads
# 955                        lever leg extension  quads
# 1007                lying (side) quads stretch  quads
# 1078                                     quads  quads
# 1080                           quick feet v. 2  quads
# 1087             resistance band leg extension  quads
# 1152                               sissy squat  quads
# 1178                         smith chair squat  quads
# 1209              smith single leg split squat  quads
# 1221                               snatch pull  quads
# 1227                              split squats  quads
# 1228                                squat jerk  quads
# 1229                        squat on bosu ball  quads
# 1230                   squat to overhead reach  quads
# 1231        squat to overhead reach with twist  quads
# 1255                     suspended split squat  quads
# 1307                      weighted sissy squat  quads
